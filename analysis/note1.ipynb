# %%
import time
import datetime as dt
import pandas as pd
from ib_insync import IB, Stock, util, Fill, Trade as IBTrade
from live.ib_client_live import IBClientLive
import nest_asyncio
nest_asyncio.apply()

from ib_insync import MarketOrder, LimitOrder, StopOrder, Order, BracketOrder, Trade, Position
from ib_insync import Stock

# %%
from ib_insync import IB, Stock, MarketOrder

ib = IB()
ib.connect('127.0.0.1', 7497, clientId=2, account='DU8057891')  # Paper TWS example

contract = Stock('AMD', 'SMART', 'USD', primaryExchange='NASDAQ')
#ib.qualifyContracts(contract)

order = MarketOrder('BUY', 1)  # Your IB account, if needed

trade = ib.placeOrder(contract, order)
print(trade)
 #
# Out:
# Trade(contract=Stock(symbol='AMD', exchange='SMART', primaryExchange='NASDAQ', currency='USD'), order=MarketOrder(orderId=10, clientId=2, action='BUY', totalQuantity=1), orderStatus=OrderStatus(orderId=10, status='PendingSubmit', filled=0.0, remaining=0.0, avgFillPrice=0.0, permId=0, parentId=0, lastFillPrice=0.0, clientId=0, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2025, 4, 8, 16, 35, 16, 555561, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0)], advancedError='')
